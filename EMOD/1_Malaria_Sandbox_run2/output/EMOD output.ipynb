# %% [markdown]
# # EMOD output

# %% [markdown]
# * Wenchang Yang (wenchang@princeton.edu)
# * Department of Geosciences, Princeton University

# %%
import json

# %%
pwd
# Out:
# '/home/wenchang/EMOD/exp/1_Malaria_Sandbox_run2/output'

# %%
ls ../
# Out:
# campaign.json  output/               run_EMOD*   time.txt
# config.json    param_overrides.json  status.txt

# %%
# !cat ../run_EMOD
# Out:
# #!/usr/bin/env bash
#
#
# # specify paths
# binary_path="/home/wenchang/EMOD/build/x64/Release/Eradication/Eradication"
# config_file="config.json"
# input_path="/home/wenchang/EMOD-InputData/Namawala"
# output_path="output"
#
# # commission job
# $binary_path -C $config_file  -I $input_path -O $output_path

# %%
ls
# Out:
# BinnedReport.json         InsetChart.json         VectorSpeciesReport.json
# DemographicsSummary.json  plotPropertyReport.py*
# EMOD output.ipynb         plotPropertyReport.pyc

# %%
js = json.loads(open('InsetChart.json').read())

# %%
js.keys()
# Out:
# dict_keys(['Header', 'Channels'])

# %%
js['Header']
# Out:
# {'DateTime': 'Thu Jul 26 11:40:06 2018',
#  'DTK_Version': '15 master(d1b1917) May 25 2018',
#  'Report_Type': 'InsetChart',
#  'Report_Version': '3.2',
#  'Start_Time': 0,
#  'Simulation_Timestep': 1,
#  'Timesteps': 1825,
#  'Channels': 26}

# %%
for key in js['Channels'].keys():
    print(key)
# Out:
# Adult Vectors
# Air Temperature
# Births
# Campaign Cost
# Cumulative Infections
# Cumulative Reported Infections
# Daily (Human) Infection Rate
# Daily Bites per Human
# Daily EIR
# Disease Deaths
# Fever Prevalence
# Human Infectious Reservoir
# Infected
# Infectious Vectors
# Land Temperature
# Log Prevalence
# Mean Parasitemia
# New Clinical Cases
# New Diagnostic Prevalence
# New Infections
# New Reported Infections
# New Severe Cases
# Parasite Prevalence
# Rainfall
# Relative Humidity
# Statistical Population

# %%
channel = 'Adult Vectors'

fig, axes = plt.subplots(1,1, figsize=(8,6))
ts = js['Channels'][channel]
plt.plot(ts['Data'])

plt.ylabel(f'{channel} [{ts["Units"]}]')
plt.xlabel('timestep')
# Out:
# Text(0.5,0,'timestep')

# %%
channel = 'Air Temperature'

fig, axes = plt.subplots(1,1, figsize=(8,6))
ts = js['Channels'][channel]
plt.plot(ts['Data'])

plt.ylabel(f'{channel} [{ts["Units"]}]')
plt.xlabel('timestep')
# Out:
# Text(0.5,0,'timestep')

# %%
channel = 'Cumulative Infections'

fig, axes = plt.subplots(1,1, figsize=(8,6))
ts = js['Channels'][channel]
plt.plot(ts['Data'])

plt.ylabel(f'{channel} [{ts["Units"]}]')
plt.xlabel('timestep')
# Out:
# Text(0.5,0,'timestep')

# %%
channel = 'Daily (Human) Infection Rate'

fig, axes = plt.subplots(1,1, figsize=(8,6))
ts = js['Channels'][channel]
plt.plot(ts['Data'])

plt.ylabel(f'{channel} [{ts["Units"]}]')
plt.xlabel('timestep')
# Out:
# Text(0.5,0,'timestep')

# %%
channel = 'Fever Prevalence'

fig, axes = plt.subplots(1,1, figsize=(8,6))
ts = js['Channels'][channel]
plt.plot(ts['Data'])

plt.ylabel(f'{channel} [{ts["Units"]}]')
plt.xlabel('timestep')
# Out:
# Text(0.5,0,'timestep')

# %%
channel = 'Infected'

fig, axes = plt.subplots(1,1, figsize=(8,6))
ts = js['Channels'][channel]
plt.plot(ts['Data'])

plt.ylabel(f'{channel} [{ts["Units"]}]')
plt.xlabel('timestep')
# Out:
# Text(0.5,0,'timestep')

# %%
channel = 'Infectious Vectors'

fig, axes = plt.subplots(1,1, figsize=(8,6))
ts = js['Channels'][channel]
plt.plot(ts['Data'])

plt.ylabel(f'{channel} [{ts["Units"]}]')
plt.xlabel('timestep')
# Out:
# Text(0.5,0,'timestep')

# %%
channel = 'New Infections'

fig, axes = plt.subplots(1,1, figsize=(8,6))
ts = js['Channels'][channel]
plt.plot(ts['Data'])

plt.ylabel(f'{channel} [{ts["Units"]}]')
plt.xlabel('timestep')
# Out:
# Text(0.5,0,'timestep')

# %%
channel = 'Rainfall'

fig, axes = plt.subplots(1,1, figsize=(8,6))
ts = js['Channels'][channel]
plt.plot(ts['Data'])

plt.ylabel(f'{channel} [{ts["Units"]}]')
plt.xlabel('timestep')
# Out:
# Text(0.5,0,'timestep')

# %%
channel = 'Relative Humidity'

fig, axes = plt.subplots(1,1, figsize=(8,6))
ts = js['Channels'][channel]
plt.plot(ts['Data'])

plt.ylabel(f'{channel} [{ts["Units"]}]')
plt.xlabel('timestep')
# Out:
# Text(0.5,0,'timestep')
